# %%
from survae.data import *
from survae.layer import *
from survae.plot import *
from survae.train import *

# %%
model_generators = [
    lambda: SurVAE(
        [
            BijectiveLayer(2, [64] * 5), OrthonormalLayer(2),
            BijectiveLayer(2, [64] * 5), OrthonormalLayer(2),
            BijectiveLayer(2, [64] * 5), OrthonormalLayer(2),
            BijectiveLayer(2, [64] * 5),
        ],
        name="NF",
    ),
    lambda: SurVAE(
        [
            Augment(2, 4),
            BijectiveLayer(4, [64] * 5), OrthonormalLayer(4),
            BijectiveLayer(4, [64] * 5), OrthonormalLayer(4),
            BijectiveLayer(4, [64] * 5), OrthonormalLayer(4),
            BijectiveLayer(4, [64] * 5),
        ],
        name="NF-augmented",
    ),
]

# %%
datasets = [Moons(), Spiral(), Ngon(), SplitLine(), Smiley()]

# %%
models = train_models(model_generators, datasets, epochs=10_000)
# Out:
#  60%|██████    | 6/10 [33:24<23:23, 350.96s/it]/home/xiaoxiae/Documents/Education/School/Heidelberg/Studium/Magisterské/3. semestr/Generative Neural Networks for the Sciences (ML)/final/survae/data.py:571: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   return 2
# 100%|██████████| 10/10 [56:19<00:00, 337.98s/it]

# %%
plot(models, datasets)
